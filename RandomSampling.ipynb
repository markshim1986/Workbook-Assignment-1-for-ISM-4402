# %%
import pandas as pd
import numpy as np

Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 1995        982 West Street, Alexandria, VA 22304
# 1996   78 Morris Street, East Northport, NY 11731
# 1997        30 Glenridge Rd., Bountiful, UT 84010
# 1998  342 West Meadowbrook Lane, Helena, MT 59601
# 1999       81 Homestead Drive, Voorhees, NJ 08043

# %%
df.take(np.random.permutation(len(df))[:500])
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 1071      Clark      Baker    male   16         5     18  100.0
# 423        Neil       Beck    male   16         2     18   91.4
# 1681    Gabriel       Goff    male   19         5     13   94.4
# 746       Chase      Wiley    male   14         1     13   90.8
# 1129      Nasim     Stuart    male   17         1     11   72.4
# 337     Orlando    Osborne    male   19         4      8   69.3
# 760   Anastasia    Goodwin  female   18         4      3   76.4
# 1846      Roary       Howe  female   16         1     18   85.4
# 698        Ruth     Bowman  female   18         3     18  100.0
# 1446      Idola   Jacobson  female   17         5      7   70.0
# 596     Breanna  Gillespie  female   19         1     12   82.5
# 308    Britanni   Fletcher  female   15         1     10   80.7
# 1782      Alvin    Bullock    male   16         1     18   90.1
# 1990      Adena     Battle  female   17         2      8   70.2
# ...
